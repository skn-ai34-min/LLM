# %%
from dotenv import load_dotenv # .env 환경변수 로드
from openai import OpenAI # 클라이언트 객체 생성 클래스
import os # 환경변수 접근

load_dotenv() # .env파일 읽어와 환경변수 등록
# OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
client = OpenAI() # OPENAI_API_KEY가 환경변수에 등록되어 있으면 (api_key = ...) 생략 가능

# %%
# Chat Completion API 호출
response = client.chat.completions.create(
    model = 'gpt-5.6-luna',
    messages = [
        # 시스템 프롬프트 : 모델의 페르소나 / 규칙 설정
        {
            "role": "system",
            "content": "당신은 세상에서 가장 친절한 챗봇입니다."
            
        },
        {
            "role": "user",
            "content": "안녕, 나는 LLM을 공부하는 학생이야~ 만나서 반갑다!"
        },
        {
            "role": "assistant", # (이전 대화 내용 중) 챗봇의 답변
            "content": "안녕! 만나서 반가워~ LLM 공부를 하고 있구나. 어떤 분야에 관심이 있는지 말해줄래?"
        },
        {
            "role": "user",
            "content": "GTP 모델은 트랜스포머와 어떤 연관성을 가지고 있는거야?"
        },
        {
            "role": "assistant",
            "content": """
좋은 질문이야! GPT 모델은 트랜스포머(Transformer) 아키텍처를 기반으로 발전했어. 간단히 설명할게.

1. **트랜스포머(Transformer)**
2017년에 "Attention is All You Need" 논문에서 소개된 트랜스포머는 자연어 처리의 혁신적인 모델 구조야. 이전 RNN이나 LSTM과 달리, 순차적인 계산 없이도 병렬 처리가 가능하고, '셀프 어텐션(Self-Attention)' 메커니즘을 사용해 문맥을 효율적으로 이해할 수 있어.

2. **GPT (Generative Pre-trained Transformer)**
GPT는 트랜스포머의 '디코더' 부분을 기반으로 한 모델이야. OpenAI가 처음 발표한 GPT는 대규모 텍스트 데이터에 대해 '언어 모델링' 방식으로 사전학습(pre-training)을 하고, 이후 특정 작업에 맞게 미세조정(fine-tuning)하는 방식을 사용했어.

3. **주요 발전 포인트**
- **사전학습과 미세조정**: GPT는 트랜스포머를 이용해 방대한 텍스트를 예측하는 작업으로 사전학습하고, 이후 다양한 언어 처리 작업에 적용할 수 있어.
- **규모 확장**: GPT-2, GPT-3, 그리고 최신 GPT-4로 갈수록 모델 크기와 학습 데이터 양이 크게 늘어나면서, 더 자연스럽고 다재다능한 언어 능력을 갖추게 됐어.
- **제로샷/원샷 학습 능력**: 큰 모델로 발전하면서 GPT는 별도 미세조정 없이도 (제로샷) 또는 적은 예시만으로도 (원샷/퓨샷) 다양한 작업을 수행할 수 있게 되었어.

정리하자면, GPT는 트랜스포머 아키텍처의 강력한 특징들을 활용해, 대규모 사전학습과 점차 확장된 모델 크기를 통해 자연어 생성 및 이해 능력을 크게 향상시킨 모델이라고 할 수 있어.

더 궁금한 점 있으면 언제든 물어봐!

            """
        },
        {
            "role": "user",
            "content": "와 너무 도움이 많이 됐어 고마워. 근데 세줄 요약좀!"
        },

    ],
    response_format = {"type": "text"}, # 응답 형식
    temperature= 1,               # 창의성/다양성 (낮으면 결정론적, 일괄적 / 높으면 창의적)
    max_completion_tokens= 4096,  # 최대 출력 토큰
    top_p=1,                      # 누적확률 p까지의 후보를 샘플링 (1은 전체사용)
)

response
# Out:
# ChatCompletion(id='chatcmpl-EEUCFILZEBBVKtB6aLXvCGAei3zOi', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='- GPT는 트랜스포머의 **디코더 구조**를 기반으로 한 언어 모델이야.\n- 셀프 어텐션으로 문맥을 파악하고, 다음 토큰을 예측하며 텍스트를 생성해.\n- 대규모 사전학습과 모델 확장을 통해 다양한 작업을 수행할 수 있게 발전했어.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787121375, model='gpt-5.6-luna', object='chat.completion', metadata=None, moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=81, prompt_tokens=612, total_tokens=693, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=0, cached_tokens=0, image_tokens=None, text_tokens=None)))

# %%
print(response.choices[0].message.content)
# Out:
# - GPT는 트랜스포머의 **디코더 구조**를 기반으로 한 언어 모델이야.
# - 셀프 어텐션으로 문맥을 파악하고, 다음 토큰을 예측하며 텍스트를 생성해.
# - 대규모 사전학습과 모델 확장을 통해 다양한 작업을 수행할 수 있게 발전했어.

# %%
messages = [{'role': 'system', 'content': '당신은 지혜로운 챗봇입니다.'}]

print("종료하려면 exit를 입력하세요.")
while True:
    user_input = input('User: ')

    if user_input.lower().strip() == 'exit':
        print('대화 종료됩니다.')
        break

    print(f"User : {user_input}")
    messages.append({'role':'user', 'content':user_input})
    response = client.chat.completions.create(
        model = 'gpt-5.6-luna',
        messages = messages,
        temperature=1,
        top_p=1,
        max_completion_tokens=4096
    )
    assistant_message = response.choices[0].message.content
    print(f"Assistant : {assistant_message}")
    messages.append({'role': 'assistant', 'content': assistant_message})
# Out:
# 종료하려면 exit를 입력하세요.
# User : 독산동의 내일 날씨는 어떻게되나요?
# Assistant : 독산동(서울 금천구)의 **내일(8월 20일) 날씨는 실시간 예보 확인이 필요합니다.** 현재 저는 최신 기상 데이터에 직접 접속할 수 없어요.
#
# 기상청 날씨누리나 네이버 날씨에서 **“서울 금천구 독산동”**을 검색하면 시간대별 기온·강수확률·미세먼지를 확인할 수 있습니다.
# User : 8월 15일은 한국에서 어떤 의미가 있나요?
# Assistant : 한국에서 **8월 15일은 광복절(光復節)**입니다.
#
# - **의미:** 1945년 8월 15일, 일본의 식민 지배에서 벗어나 국권을 되찾은 날을 기념합니다.
# - **‘광복’의 뜻:** “빛을 되찾다”라는 의미입니다.
# - **역사적 의의:** 1910년부터 이어진 일제강점기가 끝났음을 기념하는 날입니다.
# - **공휴일:** 대한민국의 국경일이자 법정 공휴일입니다.
#
# 또한 1948년 8월 15일에는 대한민국 정부 수립이 선포되어, 광복절은 독립과 정부 수립을 함께 기념하는 날로도 여겨집니다.
# 대화 종료됩니다.

# %% [markdown]
# - 일반 서비스에서 대화 저장을 처리하는 방식
#
# 1) DB에 저장 (가장 정석)
#
#     - **RDB(PostgreSQL/MySQL)**: 유저/세션/메시지 관계가 명확해서 운영에 강함
#     - **NoSQL(MongoDB 등)**: 문서 형태로 대화 전체를 한 번에 저장하기 편함
#
# 2) 캐시에 저장 (속도용) + DB에 영구 저장(혼합)
#
#     - **Redis**에 최근 N개 메시지를 캐시로 두고 빠르게 응답
#     - 일정 주기/이벤트 기준으로 **DB에 영구 저장**
#     - 장점: 빠르고 비용 효율적, 단점: Redis만 쓰면 영속성 약함(그래서 DB와 같이 씀)
#
# 3) 파일로 저장 (개인/PoC에서 가장 간단)
#
#     - JSON/JSONL 파일로 로컬에 저장
#     - 운영 서비스에서는 보통 DB로 가지만, 학습/실습/로컬 챗봇엔 매우 유용
#
# - 서비스에서 꼭 같이 고려하는 포인트
#
# A) “전체 대화”를 매번 모델에 다 보내면 비용/속도 문제가 생김
#
#     그래서 보통은:
#
#     - 최근 **N턴만** messages로 유지하거나
#     - 중간중간 **요약(summary)** 를 만들어 저장하고
#         - `system: 요약` + `최근 대화` 형태로 컨텍스트를 구성해
#
# B) 개인정보/보안
#
#     - DB에는 암호화(또는 최소한 접근 제어), 로그 마스킹
#     - API 키/토큰은 절대 대화 메시지에 저장하지 않기
#
# C) 검색형 기능(RAG)까지 갈 경우
#
#     - 전체 대화를 DB에 저장 + 중요한 메시지는 **벡터DB**에 임베딩 저장해서
#
#         “예전에 했던 얘기”를 검색해서 다시 컨텍스트에 넣는 구조도 흔함

# %%
# 스트리밍 방식 : 응답을 조각(chunk)단위로 실시간 수신
stream = client.chat.completions.create(
    model='gpt-5.6-luna',
    messages=[{'role':'user','content':'나 스트리밍 테스트 해볼건데, 아무거나 긴 답변 해줘'}],
    max_completion_tokens=2000,
    stream=True # 스트리밍 모드 활성화
)
for chunk in stream:
    content = chunk.choices[0].delta.content
    if content is not None:
        print(content, end='') # 줄바꿈 없이 이어붙임
# Out:
# 좋아요. 스트리밍 테스트에 도움이 되도록 조금 길고 자연스럽게 이어지는 글을 보내볼게요.
#
# 어느 늦은 밤, 도시의 불빛이 하나둘씩 꺼지고 사람들이 각자의 방 안으로 사라진 뒤에도, 세상은 완전히 잠들지 않는다. 멀리서 지나가는 자동차의 소리, 건물 어딘가에서 작게 울리는 냉장고의 진동, 바람에 흔들리는 나뭇잎의 마찰음, 그리고 이름 모를 새벽 배송 차량의 브레이크 소리가 어둠 사이를 천천히 지나간다. 낮에는 너무 많은 소리가 겹쳐서 잘 들리지 않던 작은 움직임들이, 밤이 되면 오히려 선명하게 모습을 드러낸다.
#
# 창문을 열면 차가운 공기가 방 안으로 들어온다. 공기에는 비가 오기 전 특유의 냄새가 아주 희미하게 섞여 있고, 멀리 있는 도로의 아스팔트는 가로등 아래에서 은은하게 빛난다. 하늘에는 구름이 많아 별은 거의 보이지 않지만, 구름 사이로 드문드문 밝은 점 하나가 모습을 드러냈다가 다시 사라진다. 아마 별일 수도 있고, 높은 건물의 옥상에 설치된 작은 불빛일 수도 있다. 중요한 것은 그것이 정확히 무엇인지보다, 어둠 속에서 무언가가 잠깐 나타났다는 사실일지도 모른다.
#
# 사람은 가끔 아무런 목적 없이 긴 글을 읽거나, 의미 없는 음악을 반복해서 듣거나, 창밖을 바라보며 시간을 보낸다. 그런 순간은 겉보기에는 아무것도 하지 않는 것처럼 보이지만, 실제로는 머릿속에 쌓여 있던 생각들이 천천히 제자리를 찾아가는 시간일 수 있다. 하루 동안 처리하지 못한 감정, 누군가에게 하지 못한 말, 내일 해야 할 일, 오래전에 지나간 장면들이 조용히 떠오른다. 어떤 생각은 금방 사라지고, 어떤 생각은 예상보다 오래 머문다. 그리고 그 과정이 끝나면, 문제 자체가 해결된 것은 아니더라도 적어도 그것을 바라보는 마음의 각도가 조금 달라져 있을 때가 있다.
#
# 아침은 언제나 갑작스럽게 찾아오는 것처럼 느껴진다. 밤새 아무 변화도 없었던 것 같은데, 어느 순간 커튼 틈 사이로 푸른빛이 스며들고, 건너편 건물의 벽이 검은색에서 회색으로, 회색에서 옅은 주황색으로 바뀐다. 길 위에는 다시 사람들이 나타난다. 누군가는 빠른 걸음으로 지하철역을 향하고, 누군가는 카페 앞에 멈춰 서서 휴대전화 화면을 확인한다. 가게의 셔터가 올라가고, 청소차가 지나가며, 빵집에서는 따뜻한 냄새가 골목으로 흘러나온다. 밤의 조용함은 사라지고, 도시는 새로운 하루를 시작할 준비를 한다.
#
# 새로운 하루가 반드시 특별할 필요는 없다. 모든 날이 중요한 사건으로 채워져야 하는 것도 아니다. 때로는 평범한 하루가 가장 오래 기억에 남는다. 제시간에 일어나서 물 한 잔을 마시고, 익숙한 길을 걷고, 잠깐 웃을 일이 생기고, 예상보다 맛있는 점심을 먹고, 저녁에 무사히 집에 돌아오는 것. 이런 사소한 일들이 쌓여 생활이라는 것을 만든다. 우리는 대단한 순간만을 기다리느라 평범한 순간이 가진 의미를 놓치곤 하지만, 인생의 대부분은 사실 이런 작은 장면들로 이루어져 있다.
#
# 생각해 보면 기술도 비슷하다. 거대한 시스템은 한 번에 완성되지 않는다. 수많은 작은 요청과 응답, 수천 개의 로그, 짧은 지연 시간, 조용히 작동하는 백그라운드 작업이 모여 하나의 서비스를 만든다. 사용자는 결과만 보지만, 그 결과 뒤에는 보이지 않는 수많은 단계가 존재한다. 데이터가 입력되고, 변환되고, 전달되고, 처리되고, 다시 화면에 나타나는 과정은 눈에 보이지 않을 정도로 빠르게 진행되지만, 그 안에는 정교한 설계와 반복적인 검증이 필요하다. 작은 오류 하나가 전체 흐름을 멈출 수도 있고, 반대로 작은 개선 하나가 많은 사람의 경험을 편리하게 바꿀 수도 있다.
#
# 스트리밍 역시 흐름에 관한 것이다. 한 번에 모든 것을 전달하는 대신, 준비된 부분부터 조금씩 보내고, 받는 쪽에서는 도착하는 내용을 즉시 보여준다. 그래서 사용자는 전체 작업이 끝날 때까지 기다리지 않아도 된다. 문장이 하나씩 나타나고, 생각이 이어지고, 화면은 계속해서 갱신된다. 이 방식은 마치 누군가가 옆자리에서 천천히 이야기를 들려주는 것과 비슷하다. 말이 끝난 뒤에 녹음 파일 전체를 재생하는 것이 아니라, 말하는 순간마다 소리가 전달되는 것이다. 그래서 중간에 멈출 수도 있고, 진행 상황을 확인할 수도 있으며, 긴 작업이 실제로 살아 움직이고 있다는 느낌을 받을 수 있다.
#
# 물론 흐름이 항상 매끄러운 것은 아니다. 네트워크가 느려질 수도 있고, 중간에 연결이 끊길 수도 있으며, 예상하지 못한 오류가 발생할 수도 있다. 하지만 중요한 것은 문제가 전혀 없는 상태가 아니라, 문제가 생겼을 때 어떻게 알아차리고 어떻게 회복하느냐이다. 잠시 멈춘 뒤 다시 이어질 수도 있고, 일부 내용을 건너뛰고 새로운 지점에서 시작할 수도 있다. 완벽하게 한 번도 흔들리지 않는 시스템보다, 흔들리더라도 안정적으로 다시 균형을 찾는 시스템이 더 신뢰할 만한 경우도 많다.
#
# 이제 글의 끝이 가까워지고 있다. 하지만 끝에 도착했다고 해서 이야기가 완전히 사라지는 것은 아니다. 읽는 사람의 머릿속에는 몇 가지 문장이나 이미지가 남을 수 있고, 그중 하나는 다른 생각을 불러올 수도 있다. 긴 답변은 정보를 많이 전달하기 위한 도구이기도 하지만, 동시에 시간의 흐름을 확인하기 위한 방법이기도 하다. 문장이 조금씩 도착하고, 화면이 계속 업데이트되며, 마지막 문장에 도달하는 순간까지 연결이 유지되는지 확인할 수 있다.
#
# 마지막으로 아주 평범한 문장을 남긴다. 오늘 하루가 완벽하지 않아도 괜찮고, 계획한 일을 모두 끝내지 못해도 괜찮다. 잠시 멈춰 숨을 고르고, 필요한 만큼 천천히 다시 시작하면 된다. 작은 변화도 변화이고, 느린 전진도 전진이다. 그리고 지금 이 문장이 스트리밍 테스트의 마지막 부분이라면, 곧 다음 단계로 넘어갈 수 있을 것이다.

# %%
messages = [{'role': 'system', 'content': '당신은 지혜로운 챗봇입니다.'}]

print("종료하려면 exit를 입력하세요.")
while True:
    user_input = input('User: ')

    if user_input.lower().strip() == 'exit':
        print('대화 종료됩니다.')
        break

    print(f"User : {user_input}")
    messages.append({'role':'user', 'content':user_input})
    response = client.chat.completions.create(
        model = 'gpt-5.6-luna',
        messages = messages,
        temperature=1,
        top_p=1,
        max_completion_tokens=4096,
        stream=True
    )
    print(f"Assistant : ", end="")
    assistant_message=''
    for chunk in response:
        content = chunk.choices[0].delta.content
        if content is not None:
            print(content, end='') # 줄바꿈 없이 이어붙임
            assistant_message += content
    print()
    # 완성된 답변은 히스토리에 저장해서 다음 턴 문맥 유지하는데 사용
    messages.append({'role':'assistant','content': assistant_message})
# Out:
# 종료하려면 exit를 입력하세요.
# User : 대중교통 뭐타고갈지 추천해줘
# Assistant : 출발지와 목적지를 알려주세요.
# 시간, 비용, 환승 횟수 중 무엇을 가장 중요하게 보는지도 알려주시면 **버스·지하철·기차·택시 중 가장 적합한 대중교통**을 추천해드릴게요.
# User : 1시간 1400원 환승1회야 지하철 탈까?
# Assistant : 응, **1시간에 1,400원이고 환승 1회라면 지하철이 괜찮아 보여요.**
# 정시성도 좋고 교통체증 영향도 적어서, 이동 시간이 크게 차이 나지 않는다면 지하철 추천해요.
#
# 다만 **출발·도착역까지 걷는 시간이 길거나 환승 통로가 복잡하면** 버스가 더 편할 수 있어요.
# 대화 종료됩니다.
