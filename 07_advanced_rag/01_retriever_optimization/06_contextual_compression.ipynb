# %% [markdown]
# # Contextual Compression Index
#
# **1. 검색 속도 및 인덱싱 효율성 향상**
#
# * 청크 수의 감소: 원문을 잘게 쪼개어 수만 개의 청크로 만드는 대신, 문서당 하나의 요약문만 인덱싱한다면 전체 벡터의 개수($N$)가 줄어든다. 결과적으로 전체 인덱스 용량($N \times d$)이 줄어들어 메모리를 절약하게 된다.
#
# * **메모리(RAM) 절약:** 인덱스 크기가 작아지므로 동일한 메모리 사양에서 더 많은 문서를 관리하거나, 더 저렴한 인프라 비용으로 시스템을 운영할 수 있다.
#
# **2. 검색 노이즈 제거 (Denoising)**
#
# * **의미적 응집도 강화:** 문서에는 질문과 상관없는 부차적인 설명이나 수식어구가 포함되어 있다. 인덱싱 단계에서 이를 제거하고 핵심 의미(Semantic core)만 남겨 저장하면, 검색 시 질문 벡터와 문서 벡터 간의 정합성이 높아져 검색 정확도가 향상된다.
# * **장문 문서 처리:** 아주 긴 문서는 임베딩 모델의 토큰 제한에 걸려 정보가 소실될 수 있다. 이를 미리 요약하여 압축 인덱스에 넣으면 문서 전체의 맥락을 검색 단계에서 더 잘 반영할 수 있다.
#
# **3. 'Multi-Vector' 전략의 활용**
#
# * **요약문 기반 검색, 원문 기반 답변:** 압축 인덱스(`ir-compressed`)에서 질문과 가장 관련 있는 요약본을 빠르게 찾아낸 뒤, 실제 LLM에게 전달할 때는 해당 요약본과 연결된(Parent-Child 관계) 원문(`ir`)을 불러오는 구조를 취할 수 있다.
# * 이를 통해 **"검색은 가볍고 정확하게, 답변은 풍부한 맥락으로"** 수행하는 하이브리드 접근이 가능하다.
#
# **4. 검색 품질의 일관성 유지**
#
# * 다양한 포맷(PDF, HTML, 로그 파일 등)의 데이터를 표준화된 요약 형태로 인덱싱하면, 데이터 소스의 형태에 구애받지 않고 일관된 검색 성능을 기대할 수 있다.
#
# **요약 및 비교**
#
# | 항목 | 원문 인덱스 검색 | 압축 인덱스 검색 (ir-compressed) |
# | --- | --- | --- |
# | **검색 대상** | 문서 청크 전체 | 요약문, 키워드, 혹은 핵심 추출문 |
# | **주요 장점** | 정보 손실 없음 | 검색 속도 빠름, 노이즈 적음 |
# | **데이터 구조** | 단순 저장 | Parent-Child 또는 요약-원문 매핑 필요 |
#
# 이러한 방식은 특히 **데이터 양이 방대하여 검색 비용이 부담되거나, 문서 하나하나의 길이가 길어 검색 정확도가 떨어질 때** 매우 유용하다.

# %%
from dotenv import load_dotenv
import os

load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['PINECONE_API_KEY'] = os.getenv('PINECONE_API_KEY')
os.environ['COHERE_API_KEY'] = os.getenv('COHERE_API_KEY')
os.environ['LANGSMITH_TRACING'] = 'true'
os.environ['LANGSMITH_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGSMITH_PROJECT'] = 'skn34-langchain'
os.environ['LANGSMITH_API_KEY'] = os.getenv('LANGSMITH_API_KEY')

# %%
import pandas as pd

document_df = pd.read_csv('documents.csv')
queries_df = pd.read_csv('queries.csv')

# %% [markdown]
# ## 문서 요약 체인 & 문서 압축

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from tqdm.auto import tqdm
import time

llm = init_chat_model('gpt-5.6-luna', temperature = 0.3)
prompt = PromptTemplate.from_template('''
당신은 정보의 본질을 빠르고 정확하게 파악해내는 요약전문가 입니다.
다음 지문에서 핵심 내용만을 효과적이고, 효율적으로 요약해주세요.

{text}
''')

output_parser = StrOutputParser()
summary_chain = prompt | llm | output_parser

compressed_texts = []
for idx, row in tqdm(document_df.iterrows(), desc='문서 요약/압축', ncols=150):
    doc_id = row['doc_id']
    content = row['content']
    summary =summary_chain.invoke({'text': content})
    compressed_texts.append({'doc_id':doc_id, 'content': summary})
    time.sleep(.5)

compressed_df = pd.DataFrame(compressed_texts)

compressed_df
# Out:
# 문서 요약/압축: 0it [00:00, ?it/s]
#    doc_id                                            content
# 0      D1  제주도는 한라산 등반, 성산일출봉 관광, 해변 활동 등 다양한 관광 명소와 체험을 ...
# 1      D2  비빔밥은 조선 시대부터 전해진 한국 대표 음식으로, 밥에 채소와 고기 등의 고명을 ...
# 2      D3  걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹이다. 대표곡으로는 “Somet...
# 3      D4             세종대왕은 훈민정음을 창제하여 한글을 보급한 조선의 제4대 임금이다.
# 4      D5           이순신 장군은 임진왜란 당시 명량 해전에서 13척의 배로 적군에 맞섰다.
# 5      D6  2024년 전 지구 평균 기온은 산업화 이전보다 약 1.2℃ 상승했으며, 해수면도 ...
# 6      D7  현재 제공된 지문이 일부만 제시되어 있어 전체 내용을 정확히 요약하기 어렵습니다.\...
# 7      D8       서울 지하철은 1~9호선이 운행되며, 서울역·강남역·종로 등이 주요 환승역이다.
# 8      D9  판소리는 소리꾼과 고수가 함께 공연하는 한국의 전통 음악이며, 대표 작품으로는 「춘...
# 9     D10  한국 축구 대표팀은 2002년 한일 월드컵 4강 진출과 2012년 런던 올림픽 동메...
# 10    D11  건강을 위해 규칙적인 식습관과 주 3회 이상의 유산소·근력 운동, 충분한 생활 관리...
# 11    D12         서울 근교 당일치기 여행지로 가평 쁘띠프랑스와 남양주 수종사 등이 소개된다.
# 12    D13  비빔밥은 지역에 따라 칼로리와 탄수화물·단백질·지방 함량이 다르다.  \n※ 지문이...
# 13    D14  지문이 중간에 끊겨 있어 완전한 요약은 어렵습니다. 현재 확인되는 핵심은 다음과 같...
# 14    D15                       가야금은 12줄로 이루어진 한국의 전통 현악기이다.
# 15    D16     전통 혼례는 절차가 복잡하며, 폐백·예단·함·폐백 음식 등 다양한 의례를 포함한다.
# 16    D17  2023년 한국 영화 흥행 순위 Top10에는 「헌트」, 「비상선언」, 「범죄도시3...
# 17    D18      윈도우즈에서 한글 그래프·차트를 정상적으로 표시하려면 한글 폰트를 설정해야 한다.
# 18    D19  코드 악취는 설계·구현 과정에서 코드 구조가 비효율적이거나 유지보수하기 어려운 상태...
# 19    D20  JUnit 5는 모듈화된 구조를 갖추고 Java 플랫폼 모듈 시스템(JPMS)을 지...
# 20    D21  제시된 지문이 불완전합니다. 현재 확인되는 핵심 내용은 다음과 같습니다.\n\n- ...
# 21    D22        싱글톤 패턴은 클래스의 인스턴스가 하나만 생성되도록 보장하는 디자인 패턴이다.
# 22    D23  Strategy 패턴은 알고리즘을 캡슐화해 서로 교체하여 사용할 수 있도록 하는 디...
# 23    D24  Command 패턴은 요청을 객체로 캡슐화해 요청을 매개변수화하고, 호출자와 실제 ...
# 24    D25  지문이 중간에 끊겨 있어 전체 내용을 정확히 요약하기 어렵습니다.  \n나머지 지문...
# 25    D26  제시된 지문이 일부만 제공되어 전체 내용을 정확히 요약하기 어렵습니다. 현재 확인되...
# 26    D27  ChromaDB와 Qdrant는 벡터 검색을 지원하는 라이브러리이며, ChromaD...
# 27    D28  Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 간결하...
# 28    D29  Self-Query Retriever는 문서의 메타데이터(제목·요약·키워드)를 분석...
# 29    D30  Multi-Hop Retrieval은 한 번의 검색으로 답하기 어려운 복합 질문을 ...

# %%
# 원문과 요약문 병합해서 비교 출력
pd.set_option('display.max_colwidth', None) # 컬럼 너비 제한 해제
pd.merge(
    document_df[['doc_id', 'content']], # 원문 df
    compressed_df, # 요약문 df
    on = 'doc_id', # 병합 기준
    suffixes = ('', '_compressed') # 중복 컬럼명 접미사
)
# Out:
#    doc_id                                            content  \
# 0      D1  제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(...
# 1      D2  비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기...
# 2      D3  걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹으로, 대표곡으로는 “Somet...
# 3      D4  세종대왕(1397~1450)은 훈민정음을 창제하여 한글을 보급한 조선의 4대 임금입...
# 4      D5  이순신 장군(1545~1598)은 임진왜란 당시 명량 해전에서 13척의 배로 133...
# 5      D6  2024년 전 지구 평균 기온은 산업화 이전 대비 약 1.2℃ 상승했으며, 해수면 ...
# 6      D7  최근 인공지능 분야에서는 생성형 AI, 멀티모달 모델, 강화학습 기반 에이전트 개발...
# 7      D8  서울 지하철은 1호선부터 9호선까지 운행되며, 주요 환승역으로는 서울역·강남역·종로...
# 8      D9  판소리는 소리꾼과 고수가 함께 공연하는 한국 전통 음악으로, 대표 작품에는 “춘향가...
# 9     D10  한국 축구 대표팀은 2002 한일 월드컵 4강 진출, 2012 런던 올림픽 동메달 ...
# 10    D11  건강을 위해서는 규칙적 식습관, 적절한 운동(주 3회 이상, 유산소+근력), 충분한...
# 11    D12  서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, ...
# 12    D13  비빔밥은 지역별로 칼로리, 탄수화물, 단백질, 지방 함량이 차이를 보입니다. 전주 ...
# 13    D14  AI를 활용한 기후 예측 연구는 기계학습 모델을 통해 대규모 기상 데이터를 분석해 ...
# 14    D15  가야금은 한국 전통 현악기로, 12개의 줄을 가진 칠현금(七絃琴) 계열 악기입니다....
# 15    D16  전통 혼례는 예식 절차가 복잡하며, 폐백, 예단, 함, 폐백음식 등 여러 의례가 포...
# 16    D17  2023년 한국 영화 흥행 순위 Top10에는 “헌트”, “비상선언”, “범죄도시3...
# 17    D18  윈도우즈 환경에서 한글이 깨지지 않고 시각화(그래프·차트)할 때는, 한글 폰트를 시...
# 18    D19  코드 악취(Bad Smell)는 설계·구현 단계에서 코드 구조가 비효율적이거나 유지...
# 19    D20  JUnit5는 모듈화된 구조(Java Platform Module System 지원...
# 20    D21  Wheel of Fortune은 랜덤으로 숫자·문자가 배치된 원판을 돌려 맞춰진 알...
# 21    D22  싱글톤(Singleton) 패턴은 클래스의 인스턴스를 한 개만 생성하도록 보장하며,...
# 22    D23  Strategy 패턴은 알고리즘 군을 캡슐화하여 상호 교환 가능하도록 만드는 패턴입...
# 23    D24  Command 패턴은 요청을 객체로 캡슐화하여 요청을 매개변수화하고, 호출자(inv...
# 24    D25  2025년 한국 정부는 “AI 국가전략 2.0”을 발표하며, 인공지능 기술 연구·개...
# 25    D26  딥러닝 모델(예: LSTM, Transformer 기반 시계열 모델)을 활용한 기상...
# 26    D27  ChromaDB와 Qdrant는 벡터 검색 라이브러리로, ChromaDB는 오픈소스...
# 27    D28  Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 압축(...
# 28    D29  Self-Query Retriever는 문서 메타데이터(제목·요약·키워드)를 분석해...
# 29    D30  Multi-Hop Retrieval은 한 단계의 검색으로 해결되지 않는 복합 질문에...
#
#                                                                                                                                                              content_compressed
# 0                                                                                                          제주도는 한라산 등반, 성산일출봉 관광, 해변 활동 등 다양한 관광 명소와 체험을 즐길 수 있는 대한민국 대표 관광지이다.
# 1                                                                                                                  비빔밥은 조선 시대부터 전해진 한국 대표 음식으로, 밥에 채소와 고기 등의 고명을 올려 비벼 먹는 음식이다.
# 2                                                                                                                       걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹이다. 대표곡으로는 “Somet…” 등이 있다.
# 3                                                                                                                                        세종대왕은 훈민정음을 창제하여 한글을 보급한 조선의 제4대 임금이다.
# 4                                                                                                                                      이순신 장군은 임진왜란 당시 명량 해전에서 13척의 배로 적군에 맞섰다.
# 5                                                                                                                        2024년 전 지구 평균 기온은 산업화 이전보다 약 1.2℃ 상승했으며, 해수면도 상승하고 있다.
# 6                                       현재 제공된 지문이 일부만 제시되어 있어 전체 내용을 정확히 요약하기 어렵습니다.\n\n**확인 가능한 핵심 내용:**  \n최근 인공지능 분야는 **생성형 AI, 멀티모달 모델, 강화학습 기반 에이전트 개발**을 중심으로 발전하고 있습니다.
# 7                                                                                                                                  서울 지하철은 1~9호선이 운행되며, 서울역·강남역·종로 등이 주요 환승역이다.
# 8                                                                                                                        판소리는 소리꾼과 고수가 함께 공연하는 한국의 전통 음악이며, 대표 작품으로는 「춘향가」가 있다.
# 9                                                                                                        한국 축구 대표팀은 2002년 한일 월드컵 4강 진출과 2012년 런던 올림픽 동메달 등 국제대회에서 뛰어난 성과를 거두었다.
# 10                                                                                                                        건강을 위해 규칙적인 식습관과 주 3회 이상의 유산소·근력 운동, 충분한 생활 관리가 필요하다.
# 11                                                                                                                                   서울 근교 당일치기 여행지로 가평 쁘띠프랑스와 남양주 수종사 등이 소개된다.
# 12                                                                                  비빔밥은 지역에 따라 칼로리와 탄수화물·단백질·지방 함량이 다르다.  \n※ 지문이 “전주 …”에서 끝나 있어 전주 비빔밥 관련 구체적 내용은 확인할 수 없습니다.
# 13                                                            지문이 중간에 끊겨 있어 완전한 요약은 어렵습니다. 현재 확인되는 핵심은 다음과 같습니다.\n\n**AI와 기계학습 모델을 활용해 대규모 기상 데이터를 분석하고 기후를 예측하는 연구가 진행되고 있다.**
# 14                                                                                                                                                 가야금은 12줄로 이루어진 한국의 전통 현악기이다.
# 15                                                                                                                               전통 혼례는 절차가 복잡하며, 폐백·예단·함·폐백 음식 등 다양한 의례를 포함한다.
# 16                                                                                                                     2023년 한국 영화 흥행 순위 Top10에는 「헌트」, 「비상선언」, 「범죄도시3」 등이 포함된다.
# 17                                                                                                                                윈도우즈에서 한글 그래프·차트를 정상적으로 표시하려면 한글 폰트를 설정해야 한다.
# 18                                                                                                                       코드 악취는 설계·구현 과정에서 코드 구조가 비효율적이거나 유지보수하기 어려운 상태를 의미합니다.
# 19                                                                                                                           JUnit 5는 모듈화된 구조를 갖추고 Java 플랫폼 모듈 시스템(JPMS)을 지원한다.
# 20                                                                       제시된 지문이 불완전합니다. 현재 확인되는 핵심 내용은 다음과 같습니다.\n\n- **Wheel of Fortune**은 숫자와 문자가 무작위로 배치된 원판을 돌리는 방식의 게임이다.
# 21                                                                                                                                  싱글톤 패턴은 클래스의 인스턴스가 하나만 생성되도록 보장하는 디자인 패턴이다.
# 22                                                                                                                       Strategy 패턴은 알고리즘을 캡슐화해 서로 교체하여 사용할 수 있도록 하는 디자인 패턴이다.
# 23                                                                                                         Command 패턴은 요청을 객체로 캡슐화해 요청을 매개변수화하고, 호출자와 실제 처리 객체를 분리하는 디자인 패턴입니다.
# 24                                                                                                 지문이 중간에 끊겨 있어 전체 내용을 정확히 요약하기 어렵습니다.  \n나머지 지문을 보내주시면 핵심 내용만 간결하게 요약해드리겠습니다.
# 25  제시된 지문이 일부만 제공되어 전체 내용을 정확히 요약하기 어렵습니다. 현재 확인되는 핵심은 다음과 같습니다.\n\n- LSTM, Transformer 기반의 딥러닝 시계열 모델을 활용해 기상 데이터를 분석·예측하려는 내용입니다.\n\n전체 지문을 보내주시면 핵심 내용 중심으로 정확하게 요약해드리겠습니다.
# 26                                                                                                                     ChromaDB와 Qdrant는 벡터 검색을 지원하는 라이브러리이며, ChromaDB는 오픈소스이다.
# 27                                                                                                                  Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 간결하게 압축하는 기법입니다.
# 28                                                                                                                   Self-Query Retriever는 문서의 메타데이터(제목·요약·키워드)를 분석하는 검색 기술입니다.
# 29                                                                                                  Multi-Hop Retrieval은 한 번의 검색으로 답하기 어려운 복합 질문을 여러 단계의 검색과 추론을 통해 해결하는 방법입니다.

# %%
from pinecone import Pinecone, ServerlessSpec # Pinecone 클라이언트, 인덱스 스펙설정

pc = Pinecone()
print(pc.list_indexes().names()) # 인덱스 이름

# 인덱스명 ir
if 'ir-compressed' not in pc.list_indexes().names():
    # 인덱스 생성
    pc.create_index(
        name = 'ir-compressed',
        dimension = 1536,
        metric = 'cosine',       # 유사도 기준
        spec = ServerlessSpec(
            region= 'us-east-1',
            cloud= 'aws'
        )
    )
    print('ir-compressed 인덱스 생성 완료!')
else:
    print('ir-compressed 인덱스 이미 존재!')
# Out:
# ['ir']
# ir 인덱스 생성 완료!

# %%
# 원본 인덱스와 압축 인덱스 PineconeVectorStore 연결
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

embeddings = OpenAIEmbeddings(model='text-embedding-3-small') # 1536차원 임베딩 모델
# 벡터스토어 연결
original_vector_store = PineconeVectorStore(
    index_name = 'ir', # 연결할 index명
    embedding = embeddings # 사용할 임베딩 함수 (연결할 인덱스 차원과 임베딩 차원이 같아야함)
)
vector_store = PineconeVectorStore(
    index_name = 'ir-compressed', # 연결할 index명
    embedding = embeddings # 사용할 임베딩 함수 (연결할 인덱스 차원과 임베딩 차원이 같아야함)
)

# %%
# 압축문서를 Document 변환 후에 Pinecone 업서트
# DataFrame -> Langchain Document 변환
from langchain_core.documents import Document # Langchain 문서 객체
from tqdm.auto import tqdm
from pprint import pprint
docs_to_index = []

for idx, row in tqdm(compressed_df.iterrows()): # df를 행 단위로 순회
    doc_id = row['doc_id']     # 문서 ID 추출
    content = row['content']   # 문서 본문 추출
    doc = Document(page_content=content, metadata={'doc_id': doc_id}) # Document 형식 저장
    docs_to_index.append(doc)

pprint(docs_to_index)
vector_store.add_documents(docs_to_index)
# Out:
# 0it [00:00, ?it/s]
# [Document(metadata={'doc_id': 'D1'}, page_content='제주도는 한라산 등반, 성산일출봉 관광, 해변 활동 등 다양한 관광 명소와 체험을 즐길 수 있는 대한민국 대표 관광지이다.'), Document(metadata={'doc_id': 'D2'}, page_content='비빔밥은 조선 시대부터 전해진 한국 대표 음식으로, 밥에 채소와 고기 등의 고명을 올려 비벼 먹는 음식이다.'), Document(metadata={'doc_id': 'D3'}, page_content='걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹이다. 대표곡으로는 “Somet…” 등이 있다.'), Document(metadata={'doc_id': 'D4'}, page_content='세종대왕은 훈민정음을 창제하여 한글을 보급한 조선의 제4대 임금이다.'), Document(metadata={'doc_id': 'D5'}, page_content='이순신 장군은 임진왜란 당시 명량 해전에서 13척의 배로 적군에 맞섰다.'), Document(metadata={'doc_id': 'D6'}, page_content='2024년 전 지구 평균 기온은 산업화 이전보다 약 1.2℃ 상승했으며, 해수면도 상승하고 있다.'), Document(metadata={'doc_id': 'D7'}, page_content='현재 제공된 지문이 일부만 제시되어 있어 전체 내용을 정확히 요약하기 어렵습니다.\n\n**확인 가능한 핵심 내용:**  \n최근 인공지능 분야는 **생성형 AI, 멀티모달 모델, 강화학습 기반 에이전트 개발**을 중심으로 발전하고 있습니다.'), Document(metadata={'doc_id': 'D8'}, page_content='서울 지하철은 1~9호선이 운행되며, 서울역·강남역·종로 등이 주요 환승역이다.'), Document(metadata={'doc_id': 'D9'}, page_content='판소리는 소리꾼과 고수가 함께 공연하는 한국의 전통 음악이며, 대표 작품으로는 「춘향가」가 있다.'), Document(metadata={'doc_id': 'D10'}, page_content='한국 축구 대표팀은 2002년 한일 월드컵 4강 진출과 2012년 런던 올림픽 동메달 등 국제대회에서 뛰어난 성과를 거두었다.'), Document(metadata={'doc_id': 'D11'}, page_content='건강을 위해 규칙적인 식습관과 주 3회 이상의 유산소·근력 운동, 충분한 생활 관리가 필요하다.'), Document(metadata={'doc_id': 'D12'}, page_content='서울 근교 당일치기 여행지로 가평 쁘띠프랑스와 남양주 수종사 등이 소개된다.'), Document(metadata={'doc_id': 'D13'}, page_content='비빔밥은 지역에 따라 칼로리와 탄수화물·단백질·지방 함량이 다르다.  \n※ 지문이 “전주 …”에서 끝나 있어 전주 비빔밥 관련 구체적 내용은 확인할 수 없습니다.'), Document(metadata={'doc_id': 'D14'}, page_content='지문이 중간에 끊겨 있어 완전한 요약은 어렵습니다. 현재 확인되는 핵심은 다음과 같습니다.\n\n**AI와 기계학습 모델을 활용해 대규모 기상 데이터를 분석하고 기후를 예측하는 연구가 진행되고 있다.**'), Document(metadata={'doc_id': 'D15'}, page_content='가야금은 12줄로 이루어진 한국의 전통 현악기이다.'), Document(metadata={'doc_id': 'D16'}, page_content='전통 혼례는 절차가 복잡하며, 폐백·예단·함·폐백 음식 등 다양한 의례를 포함한다.'), Document(metadata={'doc_id': 'D17'}, page_content='2023년 한국 영화 흥행 순위 Top10에는 「헌트」, 「비상선언」, 「범죄도시3」 등이 포함된다.'), Document(metadata={'doc_id': 'D18'}, page_content='윈도우즈에서 한글 그래프·차트를 정상적으로 표시하려면 한글 폰트를 설정해야 한다.'), Document(metadata={'doc_id': 'D19'}, page_content='코드 악취는 설계·구현 과정에서 코드 구조가 비효율적이거나 유지보수하기 어려운 상태를 의미합니다.'), Document(metadata={'doc_id': 'D20'}, page_content='JUnit 5는 모듈화된 구조를 갖추고 Java 플랫폼 모듈 시스템(JPMS)을 지원한다.'), Document(metadata={'doc_id': 'D21'}, page_content='제시된 지문이 불완전합니다. 현재 확인되는 핵심 내용은 다음과 같습니다.\n\n- **Wheel of Fortune**은 숫자와 문자가 무작위로 배치된 원판을 돌리는 방식의 게임이다.'), Document(metadata={'doc_id': 'D22'}, page_content='싱글톤 패턴은 클래스의 인스턴스가 하나만 생성되도록 보장하는 디자인 패턴이다.'), Document(metadata={'doc_id': 'D23'}, page_content='Strategy 패턴은 알고리즘을 캡슐화해 서로 교체하여 사용할 수 있도록 하는 디자인 패턴이다.'), Document(metadata={'doc_id': 'D24'}, page_content='Command 패턴은 요청을 객체로 캡슐화해 요청을 매개변수화하고, 호출자와 실제 처리 객체를 분리하는 디자인 패턴입니다.'), Document(metadata={'doc_id': 'D25'}, page_content='지문이 중간에 끊겨 있어 전체 내용을 정확히 요약하기 어렵습니다.  \n나머지 지문을 보내주시면 핵심 내용만 간결하게 요약해드리겠습니다.'), Document(metadata={'doc_id': 'D26'}, page_content='제시된 지문이 일부만 제공되어 전체 내용을 정확히 요약하기 어렵습니다. 현재 확인되는 핵심은 다음과 같습니다.\n\n- LSTM, Transformer 기반의 딥러닝 시계열 모델을 활용해 기상 데이터를 분석·예측하려는 내용입니다.\n\n전체 지문을 보내주시면 핵심 내용 중심으로 정확하게 요약해드리겠습니다.'), Document(metadata={'doc_id': 'D27'}, page_content='ChromaDB와 Qdrant는 벡터 검색을 지원하는 라이브러리이며, ChromaDB는 오픈소스이다.'), Document(metadata={'doc_id': 'D28'}, page_content='Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 간결하게 압축하는 기법입니다.'), Document(metadata={'doc_id': 'D29'}, page_content='Self-Query Retriever는 문서의 메타데이터(제목·요약·키워드)를 분석하는 검색 기술입니다.'), Document(metadata={'doc_id': 'D30'}, page_content='Multi-Hop Retrieval은 한 번의 검색으로 답하기 어려운 복합 질문을 여러 단계의 검색과 추론을 통해 해결하는 방법입니다.')]
# ['dac7be49-03ed-43bb-9473-d210851aa530',
#  '7ef7e89a-d5e8-4a4c-8ac2-871142c4b4d9',
#  '6caa740a-9b1e-4803-955b-3553b1b2630e',
#  '56374653-9f97-4ce3-8286-2dc8c3501334',
#  'f57c43e5-bf42-4e3b-8ef8-56bd5277e41f',
#  '73caf002-e177-4f04-b0b0-fb3a3608a3a0',
#  '4b6d5b83-8d6a-422e-abbd-085466999343',
#  '8b3583b0-9036-4f57-a15e-34ea7359481f',
#  '88dc32ea-fce9-442d-9da8-c42966c2a903',
#  '37174d65-0b8e-445f-a127-3bc7e07d344a',
#  '8e061af5-cd36-4082-978c-418dac146969',
#  '24730e7d-82bc-4304-b928-6a3c11097ada',
#  'd83e1003-d7e5-499b-8e2d-ed0bcd1c53b6',
#  '423b44b2-d831-45b7-846c-1fc6c4074aa2',
#  '5ee84730-9204-43c1-a731-61912c857349',
#  'b2cfeead-1134-4eba-800d-59c2dacac531',
#  '455f7e16-c9ca-4dd4-8b2b-eab0422c874f',
#  'ab14d065-46fa-46b6-903c-9e1b4e699f3e',
#  'fca51b26-fca8-4611-a3af-f2d7ac2b3300',
#  '735d3085-87e7-4703-938f-625c4f012326',
#  'b3faff98-47b0-439d-9b80-b15899cddaa2',
#  '22ca28c4-1231-4f34-8baf-fce96c000a19',
#  '4a21cf1a-93d9-4f0a-9876-18ba7df63b4d',
#  '72d29858-15c0-48af-9f39-f4c23170f0a4',
#  '4d29d9ed-39e0-47e2-8778-5ce75ae350d8',
#  'bc58d905-c88f-4981-bd34-6cce5e6f0ee7',
#  'b6432108-436d-42ca-a7da-8a8df5e77380',
#  'caa774d4-b98a-4812-b39f-96d55de687d8',
#  'b7865037-6d22-4bfe-9705-1a346b45458b',
#  'a987766b-5b6f-4ba3-924f-8aa10443bbef']

# %%
import numpy as np

def parse_relevant(relevant_str) -> dict[str, int]:
    '''
    참조문서 답안 문자열을 dict로 파싱하는 함수

    relevant_str = "D1=3;D4=1;D30=1" -> {'D1': 3, 'D4': 1, 'D30': 1}
    '''
    pairs = relevant_str.split(';')
    rel_dict = {}

    for pair in pairs:
        doc_id, grade = pair.split('=')
        rel_dict[doc_id] = int(grade)
    return rel_dict
# 예측 결과와 실제 정답을 비교해서 평가지표를 계산하는 함수
def compute_metrics(predicted, relevant_dict, k=5) -> tuple[float, float, float, float]:
    # Precision@k
    hits = sum([1 for doc in predicted[:k] if doc in relevant_dict]) # top-k 적중 개수
    precision = hits / k # 정밀도 = 맞춘갯수 / 전체갯수
    # Recall@k
    total_relevant = len(relevant_dict) # 전체 관련 문서 수
    recall = hits / total_relevant if total_relevant > 0 else 0 # 재현율 = 관련 문서 맞춘 수

    # MRR 예측치 중 첫 관련문서 순위 점수
    rr = 0 # 관련 문서 수
    # 전체 랭킹에서 첫번째 적중된 것을 찾음
    for idx, doc in enumerate(predicted):
        if doc in relevant_dict:
            rr = 1 / (idx + 1) # 첫 적중 순위 역수
            break # 첫 번째 적중 rr 반영 후 break

    # AP (MAP를 위한 사전 계산)
    num_correct = 0 # 현재까지의 적중 횟수
    precisions = [] # 적중시의 precision
    for idx, doc in enumerate(predicted[:k]): # top-k 범위에서 
        if doc in relevant_dict:
            num_correct += 1
            precisions.append(num_correct / (idx + 1)) # 현재 시점의 precision 기록
    ap = np.mean(precisions) if precisions else 0 # precision 평균치 사용, 없으면 0

    return precision, recall, rr, ap
# 여러 쿼리에 대한 평균 성능지표 계산하는 함수
def evaluate_all(method_results, queries_df, k=5):
    prec_list, rec_list, rr_list, ap_list = [], [], [], []

    for idx, row in queries_df.iterrows():
        qid = row['query_id']
        relevant_dict = parse_relevant(row['relevant_doc_ids']) # 정답 dict 파싱
        predicted = method_results[qid] # 해당 쿼리의 에측 랭킹
        p, r, rr, ap = compute_metrics(predicted, relevant_dict, k) # 지표 계산
        prec_list.append(p)
        rec_list.append(r)
        rr_list.append(rr)
        ap_list.append(ap) 

    return {
        'P@k': np.mean(prec_list), # 쿼리 평균 Precision@k
        'R@k': np.mean(rec_list),  # 쿼리 평균 Recall@k
        'MRR': np.mean(rr_list),   # 쿼리 평균 MRR
        'MAP': np.mean(ap_list),   # 쿼리 평균 MAP
    }

# %%
original_results = {} # {qid: [doc_id, ...], ...}
compressed_results = {} # {qid: [doc_id, ...], ...}
top_k = 5

for idx, row in tqdm(queries_df.iterrows()):
    qid = row['query_id']
    query_text = row['query_text']

    docs_from_original = original_vector_store.similarity_search(query_text,k=top_k)
    original_results[qid] = [doc.metadata['doc_id'] for doc in docs_from_original]

    docs = original_vector_store.similarity_search(query_text,k=top_k)
    compressed_results[qid] = [doc.metadata['doc_id'] for doc in docs]
# Out:
# 0it [00:00, ?it/s]

# %%
original_metrics = evaluate_all(original_results, queries_df, k=5)
compressed_metrics = evaluate_all(compressed_results, queries_df, k=5)

# %%
metrics_df = pd.DataFrame({
    'Metrics': ['P@5', 'R@5', 'MRR', 'MAP'],
    'Original': [original_metrics['P@k'], original_metrics['R@k'], original_metrics['MRR'], original_metrics['MAP']],
    'Compressed': [compressed_metrics['P@k'], compressed_metrics['R@k'], compressed_metrics['MRR'], compressed_metrics['MAP']]
})
metrics_df
# Out:
#   Metrics  Original  Compressed
# 0     P@5  0.246667    0.246667
# 1     R@5  0.888889    0.888889
# 2     MRR  0.950000    0.950000
# 3     MAP  0.920556    0.920556

# %%
import matplotlib.pyplot as plt

metrics = ['P@5', 'R@5', 'MRR', 'MAP']
original_vals = [original_metrics['P@k'], original_metrics['R@k'], original_metrics['MRR'], original_metrics['MAP']]
compressed_vals = [compressed_metrics['P@k'], compressed_metrics['R@k'], compressed_metrics['MRR'], compressed_metrics['MAP']]

x = range(len(metrics))

plt.figure(figsize=(8, 4))
plt.plot(x, original_vals, marker='o', label='Original')
plt.plot(x, compressed_vals, marker='s', label='Compressed')
plt.xticks(x, metrics)
plt.ylim(0, 1.1)
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Original vs Compressed Retrival')
plt.legend()
plt.grid()
plt.show()
